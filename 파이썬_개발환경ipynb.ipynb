# %% [markdown]
# <a href="https://colab.research.google.com/github/chaegeon/Multi-learning/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC_%EA%B0%9C%EB%B0%9C%ED%99%98%EA%B2%BDipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 파이썬 설치
# - [파이썬 공식 홈페이지](http://www.python.org) - 다운로드에서 윈도우버젼으로
#   - 3파이썬가 있고 파이썬2가 있는데 2는 곧 사라지니 쓰지 말자
#   - 보통 가장 최신버젼으로 받자
#   - stable Releases 가 안정화된 버젼이라는 뜻
#   - pre-releases 는 곧 나올 예정인, 테스트버젼
#
#   - 설치 버전인 installer 로 받자
#     - 32bit / 64bit 는 구분가능하지?
#       - 탐색기 - 내Pc 속성
#
#
#   - **!중요! 설치할 때 맨 밑에 add python to ~~ PATH 체크하기**
#   - 그 다음부턴 커스터마이즈 하지 말고 그냥 인스톨
#
#
# - 파이썬 인터프리터의 설치
#   - 파이썬은 기본적으로 한 버전만 설치하는 것이 원칙이다.
#   - 여러개의 버전을 동시에 여러개 설치해서 사용할 수 없다는 의미.
#       - 억지로 쓸 수는 있지만 그렇게 사용하지 않음
#
#   - 주의사항
#     - 'Add to python to PATH' 항목 체크
#
#
#   - 파이썬 쉘을 종료할 땐 Ctrl + Z

# %% [markdown]
# ## 가상환경
# - 가상환경을 이용하면 여러 개의 파이썬 버전을 설치해서 격리된 환경을 구축하는 것이 가능
#   - 버전 별로 사용할 수 있는 라이브러리가 달라서
# - 파이썬에서는 가상환경을 지원하는 여러가지 프로그램
#   - Anaconda, VirtualEnc ...
#   - 수업에서는 아나콘다 쓸 것
#
# -Anaconda 설치
#   - [Anaconda](https://www.anaconda.com/products/individual)
#   - 다운로드 눌렀을 때 뭐 이메일이랑 뜨는 건 그냥 닫아도 됨
#   - 설치는 웬만하면 긍정적인 답변으로 체크
#     - next, i agree, intall ... 으로
#     - ! 주의 !
#     - 설치 도중 'Advances Installation Option'에서 'Add Anaconda to the system Path environment variable' 항목을 체크하자
#     - 여럿이 볼 수 있게 하자 그냥
#     - 설치 경로 바꾸지 말자 (나중에 사용할 때 복잡하고 문제가 생길 수도)
#     - Add anaconda to rhe system PATH environment ~~~ 체크해주자
#     - 마지막 창에서 튜토리얼 등 2개 체크 해제하고 finish 누르면 끝남
#
#   - 일반적으로 아나콘다는 CLI 기반의 명령어를 통해서 가상환경을 생성, 삭제, 확인 ...
#     - CLI : Command Line Interface
#       - 데이터 엔지니어링은 전부 CLI 기반이다.
#       - 마우스 뭐 이런 거 없음
#       - 명령어기반이라 명령어들 다 알고 있어야 됨
#
#     - GLI : Graphic Line Interface
#
#
# - 네비게이터
#   - 왼쪽에 인바이러먼츠
#     - 베이스
#       - 여기서 가상환경을 추가, 복제, 삭제 등 관리 할 수 있음
#
#   - creat 누르면 가상환경 추가 가능
#     - 웬만하면 한글이름 말고 영어로 만들자 Ex). multicampus
#       - 패키지 칸에서 파이썬 버전을 선택할 수 있음 Ex) 3. 10
#
#   - 가상관경을 추가 했는데 추가하다 말고 베이스만 남는 문제
#     - 파일 경로에 한글이 들어가서?!
#     - 컴퓨터 계정이 한글계정이면 문제가 될 수도
#     - 근데 영어로 바꿔봤는데도 안 된다고 하는 사람이 있음
#     - 계정을 새로 만들면 될 수도
#       - 제어판에서 뭐 계정 뭐... 잘 찾아보자
#       1. 가족 및 다른 사용자
#       2. 이 PC에 다른 사용자추가
#       3. 이사람의 로그인정보를 가지고있지 않습니다? 클릭
#       4. 마이크로소프트 계정?
#       5. 계정유형을 표준사용자?말고 관리자로 생성
#
#     - Admin계정으로 로그인을 하든가?

# %% [markdown]
# ## IDE ( integrated Development Environment)
# - 통합 개방환경
#   - 지난 수업시간까지 사용했던 IDE '주피터'라는 IDE를 사용
#   - 로컬환경에서 사용가능한 또다른 개발환경
#   - 아나콘다 설치하면 주피터도 깔림
#     - 주피터 노트북 뭐라 써있는 거
#   - `Visual Studio Code`
#     - 'Visual Studio' 라는 이름도 같고 비슷하게 생긴 개발도구도 있으니 헷갈리지 말자
#     - 같은 MS회사 제품이지만 전혀 다른 개발도구이다
#     - (GIT 특강 때 깔긴 했었었음)
#
# ### VSCode
#   - 파이썬이 아니어도 다른 개발에도 사용이 가능
#   - [다운로드](https://code.visualstudio.com/download)
#   - 보통 ID라 하면,
#   - 컴파일러(인터프리터) + 에디터 + 디버거 + 여러 유틸 등을 합쳐놓은 거라 생각하면 됨
#     - VS코드는 인터프리터는 없음. 따로 설치해줘야 함
#     - 그래서 아나콘다에서 가상환경을 만들어 둔 거고, 그걸 VS코드에서 사용하려는 것
#
# - VSCode설치
#   - 디폴트 경로 웬만하면 변경하지 말고 설치
#   - 체크항목 PATH에 추가는 그냥 둬도 될 듯
#
# - VSCode 에서 Python 익스텐션 설치
#   - 그 앱 설치하는 것처럼 까는 거
#   - 작업하는 거 저장할 폴더 하나 만들기
#     - 나는 TIL 폴더처럼 홈폴더에 만들었음
#   - VSCode에서 파일 - 폴더 열기로 열기
#
#   - Select Interpreter
#     - 좌측하단 파란줄 보면 파이썬 버젼 있는데 그거 클릭하면 그 아나콘다에서 만든 가상환경을 선택할 수 있나보다
#     - 그래야 'hello python' 을 입력했을 때 출력이 되는 듯
#     - 네비게이터를 키고 VSCode를 실행해야 되는 듯?
#
#
# - git desktop ?
#   - 윈도우즈에서 git을 편리하게 관리할수 있다는데 뭔지 잘 모르겠음
# - bitbucket ?
#   - github스토리지 관리?
# - gitgraph
#   - FT님이 추천
#
# -git hub 주의할 점?
#   - 취업할 때 포트폴리오 파일 같은 거 대신에 깃헙 주소로 제출을 할텐데
#   - 커밋, 푸쉬를 얼마나 했는지 확인할 수 있음
#   - 그래서 꾸준히 하던 건지 티가 남

# %% [markdown]
# # 웹프로그래밍 개발 환경
# - HTML, CSS, JavaScript
#   - 기존에 알고 있던 파이썬 같은 것들과는 좀 다름. 결이 다름
#   - 저 셋을 합쳐서 프론트-엔드 라고 한다.
#     - 회면에 보여지는 애들
#   - VSCode에서 다 실습을 해볼 수 있다.
#
# - JavaScript
#   - [node.js](https://nodejs.org/ko/download/): 자바스크립트를 실행하기 위한 인터프리터
#     - 윈도우즈 용으로 설치
#   - 설치
#     - 경로같은 거 바꾸지 말고 Next
#     - 체크 항목 하나 있는 단계도 그냥 next
#     - 설치 끝
#
# - 설치가 끝났다면 VSCode 에서 확장 프로그램 설치
#   - Code Runner 패키지 설치
#     - 자바스크립트 JS 아이콘 말고 코드러너.. 이걸로 실행할 거임
#     -
#     -
#     -
#
#
#
# - 코드러너 설치까지 들었는데 hello javascript 출력했는데 글씨깨지는 걸 해결했다고 하는 것까지.. 그 사이를 못 들었음
# - js 파일을 생성했나본데?...
# - 파일 생성했으면 저장을 꼭 눌러줄 것
#
# - html 파일을 생성하는 것부터 다시 들음
#     - ! + Tap 또는 엔터 하면 뭐 코드들 나옴
#     - 안 나온다면
#       - 오른 쪽 아래에 장고.html이 뭐죠? 라는 질문에 HTML설정을 다시 했더니 됨
#       - 장고를 깔아야 되는건가?
#
#
# - HRML & CSS
#   - 테스트를 위해서 아래의 방법으로 코드를 자동으로 생성해준다
#   - ! + Tap
#   - html:5 + Tap
# - 확장패키지 설치
#   - Open in browser
#     - 파일 탭에서 우클릭 - open in Default browser 선택
#   - Live Server
#     - 에디터에서 우클릭 - open in live Server 선택 (에디터는 그 터미널 윗부분 인 듯?)
#   -
#   - 그 12시 방향 파일 제목에 우클릭하면 설정들 막 나옴
#
# - `</h> HTML 테스트 페이지 </h1>`
# - 이거 적은건가?
# - 이거 열었을 때 엣지 말고 크롬으로 열고 싶다면
#   - 설정 - 앱 접속하셔서 기본 브라우저 변경하시면 된다.
